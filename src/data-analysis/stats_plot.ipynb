# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import networkx as nx

# %matplotlib inline

# %% [markdown]
# # Course statistics

# %% [markdown]
# In this notebook we will retrieve statistics for each course. In our final visualization, clicking on a course will open a chart in which we will be able to see some insights about the past of that course. Here, we build a dataset ad-hoc for our needs: this will enhance the performance of our website, because we won't need to recompute everytime the statistics needed for the plots.

# %% [markdown]
# ## 1. Professor

# %% [markdown]
# One important information for a course is the professor (or the list of professors) who is lecturing the course.

# %%
df_course = pd.read_csv('../../data/csv/courses.csv')
df_course.head()
# Out:
#    Unnamed: 0  course_id                             course_name       year
# 0           0          0  Biological and physiological transport  2006-2007
# 1           1          1  Biological and physiological transport  2007-2008
# 2           2          2       Special topics in reactor physics  2015-2016
# 3           3          3       Special topics in reactor physics  2014-2015
# 4           4          4       Special topics in reactor physics  2013-2014

# %%
df_teaching = pd.read_csv('../../data/csv/teaching.csv')
df_teaching.head()
# Out:
#    Unnamed: 0  course_id                 prof
# 0           0          0        Swartz Melody
# 1           2          1        Swartz Melody
# 2           7          2        Pautz Andreas
# 3          13          3        Pautz Andreas
# 4          21          4  Mikityuk Konstantin

# %% [markdown]
# After we loeaded the dataset, we want to retrieve for each course (name) who was the lecturer the last time it was held.

# %%
df_course_last = df_course.copy()
df_course_last['year'] = df_course['year'].apply(lambda x: int(x[:4]))
df_course_last = df_course_last.sort_values('year', ascending=False)
df_course_last = df_course_last.drop_duplicates('course_name')

# %%
# Counting the number of courses which ended in each year
df_course_last.groupby('year').count()
# Out:
#       Unnamed: 0  course_id  course_name
# year
# 2004         198        198          198
# 2005         122        122          122
# 2006         132        132          132
# 2007         131        131          131
# 2008         150        150          150
# 2009         179        179          179
# 2010         134        134          134
# 2011         145        145          145
# 2012         134        134          134
# 2013         122        122          122
# 2014         117        117          117
# 2015         103        103          103
# 2016         126        126          126
# 2017         125        125          125
# 2018         178        178          178
# 2019        1077       1077         1077

# %%
df_last_prof = df_course_last.merge(df_teaching, on='course_id')[['course_name', 'prof']]\
        .groupby('course_name')['prof'].apply(list).to_frame()
df_last_prof.head()
# Out:
#                                                                       prof
# course_name
#  Numerical approximation of PDE's II                       [Picasso Marco]
# 3D Electron Microscopy and FIB-Nanotomography              [Cantoni Marco]
# A History of Evolutionary Theory                    [Jensen Jeffrey David]
# A Political History of Urban Form                   [Aureli Pier Vittorio]
# A guided tour for engineers in applied stochast...   [Hongler Max-Olivier]

# %%
df_last_prof.to_csv('../../data/csv/server/course_professor_v0.csv')

# %% [markdown]
# ## 2. Number of enrolled students by year, semester, major

# %%
df_student = pd.read_csv('../../data/csv/student.csv')
df_enrollment = pd.read_csv('../../data/csv/enrollment.csv')

# %%
df_complete = df_course.merge(df_enrollment, on='course_id').merge(df_student, on='student_id')
df_complete.head()
# Out:
#    Unnamed: 0_x  course_id                             course_name       year  \
# 0             0          0  Biological and physiological transport  2006-2007
# 1           381        381                            Biomaterials  2006-2007
# 2          1435       1435             Instrumentation bio-optique  2006-2007
# 3          1442       1442    Capteurs en instrumentation médicale  2006-2007
# 4          1779       1779    Drug discovery from bench to clinics  2006-2007
#
#    Unnamed: 0_y  student_id           semester  Unnamed: 0       student_name  \
# 0             0        3692  Master semestre 2        3692  Berlier Guillaume
# 1         14382        3692  Master semestre 1        3692  Berlier Guillaume
# 2         74292        3692  Master semestre 1        3692  Berlier Guillaume
# 3         74354        3692  Master semestre 2        3692  Berlier Guillaume
# 4         86653        3692  Master semestre 2        3692  Berlier Guillaume
#
#          section
# 0  Bioingénierie
# 1  Bioingénierie
# 2  Bioingénierie
# 3  Bioingénierie
# 4  Bioingénierie

# %%
df_course_stud = df_complete[['course_name', 'year', 'semester', 'section', 'student_id']]
df_course_stud = df_course_stud.groupby(['course_name', 'year', 'semester', 'section']).agg('count')\
    .rename(columns={'student_id': 'nr_students'}).reset_index()
df_course_stud.head()
# Out:
#                             course_name       year           semester  \
# 0   Numerical approximation of PDE's II  2012-2013  Master semestre 2
# 1   Numerical approximation of PDE's II  2012-2013  Master semestre 2
# 2   Numerical approximation of PDE's II  2012-2013  Master semestre 2
# 3   Numerical approximation of PDE's II  2013-2014  Master semestre 2
# 4   Numerical approximation of PDE's II  2013-2014  Master semestre 2
#
#                                    section  nr_students
# 0                  Ingénierie mathématique            4
# 1                   Mathématiques - master            1
# 2  Science et ingénierie computationnelles            2
# 3                   Mathématiques - master            2
# 4  Science et ingénierie computationnelles            2

# %%
df_course_stud.to_csv('../../data/csv/server/course_stud.csv')

# %% [markdown]
# Analyzing further the semester and the major to better understand which visualization could be themost appropriate.

# %%
df_course_stud[['course_name', 'year', 'semester', 'section']].drop_duplicates()\
    .groupby(['course_name', 'year', 'semester']).agg('count').reset_index()\
    .sort_values('section', ascending=False).head(5)
# Out:
#      course_name       year             semester  section
# 928  Analyse III  2007-2008  Bachelor semestre 3       19
# 929  Analyse III  2008-2009  Bachelor semestre 3       18
# 927  Analyse III  2006-2007  Bachelor semestre 3       18
# 926  Analyse III  2005-2006  Bachelor semestre 3       15
# 950  Analyse IV   2008-2009  Bachelor semestre 4       13

# %%
tmp = df_complete[['course_name', 'year', 'semester', 'section', 'student_id']]\
    .groupby(['course_name', 'year', 'semester', 'section']).count()\
    .reset_index()
tmp[(tmp['course_name'] == 'Analyse III') & (tmp['year'] == '2007-2008')]
# Out:
#       course_name       year             semester  \
# 1424  Analyse III  2007-2008  Bachelor semestre 3
# 1425  Analyse III  2007-2008  Bachelor semestre 3
# 1426  Analyse III  2007-2008  Bachelor semestre 3
# 1427  Analyse III  2007-2008  Bachelor semestre 3
# 1428  Analyse III  2007-2008  Bachelor semestre 3
# 1429  Analyse III  2007-2008  Bachelor semestre 3
# 1430  Analyse III  2007-2008  Bachelor semestre 3
# 1431  Analyse III  2007-2008  Bachelor semestre 3
# 1432  Analyse III  2007-2008  Bachelor semestre 3
# 1433  Analyse III  2007-2008  Bachelor semestre 3
# 1434  Analyse III  2007-2008  Bachelor semestre 3
# 1435  Analyse III  2007-2008  Bachelor semestre 3
# 1436  Analyse III  2007-2008  Bachelor semestre 3
# 1437  Analyse III  2007-2008  Bachelor semestre 3
# 1438  Analyse III  2007-2008  Bachelor semestre 3
# 1439  Analyse III  2007-2008  Bachelor semestre 3
# 1440  Analyse III  2007-2008  Bachelor semestre 3
# 1441  Analyse III  2007-2008  Bachelor semestre 3
# 1442  Analyse III  2007-2008  Bachelor semestre 3
#
#                                         section  student_id
# 1424                                Génie civil          53
# 1425                            Génie mécanique          53
# 1426           Génie électrique et électronique          43
# 1427                               Informatique          57
# 1428          Ingénierie des sciences du vivant          62
# 1429                              Mathématiques          38
# 1430                             Microtechnique          75
# 1431                        Passerelle HES - EL           4
# 1432                        Passerelle HES - GC           2
# 1433                        Passerelle HES - GM           2
# 1434                        Passerelle HES - IN           2
# 1435                        Passerelle HES - MT           3
# 1436                        Passerelle HES - PH           1
# 1437                        Passerelle HES - SC           4
# 1438                       Passerelle HES - SIE           1
# 1439                                   Physique          54
# 1440             Science et génie des matériaux          27
# 1441  Sciences et ingénierie de l'environnement          51
# 1442                  Systèmes de communication          49

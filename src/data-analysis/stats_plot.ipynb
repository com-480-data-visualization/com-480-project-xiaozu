# %%
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import networkx as nx

# %matplotlib inline

# %% [markdown]
# # Course statistics

# %% [markdown]
# In this notebook we will retrieve statistics for each course. In our final visualization, clicking on a course will open a chart in which we will be able to see some insights about the past of that course. Here, we build a dataset ad-hoc for our needs: this will enhance the performance of our website, because we won't need to recompute everytime the statistics needed for the plots.

# %% [markdown]
# ## 1. Professor

# %% [markdown]
# One important information for a course is the professor (or the list of professors) who is lecturing the course.

# %%
df_course = pd.read_csv('../../data/csv/courses.csv')
df_course.head()
# Out:
#    Unnamed: 0  course_id                             course_name       year
# 0           0          0  Biological and physiological transport  2006-2007
# 1           1          1  Biological and physiological transport  2007-2008
# 2           2          2       Special topics in reactor physics  2015-2016
# 3           3          3       Special topics in reactor physics  2014-2015
# 4           4          4       Special topics in reactor physics  2013-2014

# %%
df_teaching = pd.read_csv('../../data/csv/teaching.csv')
df_teaching.head()
# Out:
#    Unnamed: 0  course_id                 prof
# 0           0          0        Swartz Melody
# 1           2          1        Swartz Melody
# 2           7          2        Pautz Andreas
# 3          13          3        Pautz Andreas
# 4          21          4  Mikityuk Konstantin

# %% [markdown]
# After we loeaded the dataset, we want to retrieve for each course (name) who was the lecturer the last time it was held.

# %%
df_course_last = df_course.copy()
df_course_last['year'] = df_course['year'].apply(lambda x: int(x[:4]))
df_course_last = df_course_last.sort_values('year', ascending=False)
df_course_last = df_course_last.drop_duplicates('course_name')

# %%
df_course_last.groupby('year').count()
# Out:
#       Unnamed: 0  course_id  course_name
# year
# 2004         198        198          198
# 2005         122        122          122
# 2006         132        132          132
# 2007         131        131          131
# 2008         150        150          150
# 2009         179        179          179
# 2010         134        134          134
# 2011         145        145          145
# 2012         134        134          134
# 2013         122        122          122
# 2014         117        117          117
# 2015         103        103          103
# 2016         126        126          126
# 2017         125        125          125
# 2018         178        178          178
# 2019        1077       1077         1077

# %%
df_last_prof = df_course_last.merge(df_teaching, on='course_id')[['course_name', 'prof']]\
        .groupby('course_name')['prof'].apply(list).to_frame()
df_last_prof.head()
# Out:
#                                                                       prof
# course_name
#  Numerical approximation of PDE's II                       [Picasso Marco]
# 3D Electron Microscopy and FIB-Nanotomography              [Cantoni Marco]
# A History of Evolutionary Theory                    [Jensen Jeffrey David]
# A Political History of Urban Form                   [Aureli Pier Vittorio]
# A guided tour for engineers in applied stochast...   [Hongler Max-Olivier]

# %%
df_last_prof.to_csv('../../data/csv/server/course_professor_v0.csv')

# %% [markdown]
# ## 2. Number of enrolled students by year

# %%
df_student = pd.read_csv('../../data/csv/student.csv')
df_enrollment = pd.read_csv('../../data/csv/enrollment.csv')

# %%
df_complete = df_course.merge(df_enrollment, on='course_id').merge(df_student, on='student_id')
df_complete.head()
# Out:
#    Unnamed: 0_x  course_id                             course_name       year  \
# 0             0          0  Biological and physiological transport  2006-2007
# 1           381        381                            Biomaterials  2006-2007
# 2          1435       1435             Instrumentation bio-optique  2006-2007
# 3          1442       1442    Capteurs en instrumentation médicale  2006-2007
# 4          1779       1779    Drug discovery from bench to clinics  2006-2007
#
#    Unnamed: 0_y  student_id           semester  Unnamed: 0       student_name  \
# 0             0        3692  Master semestre 2        3692  Berlier Guillaume
# 1         14382        3692  Master semestre 1        3692  Berlier Guillaume
# 2         74292        3692  Master semestre 1        3692  Berlier Guillaume
# 3         74354        3692  Master semestre 2        3692  Berlier Guillaume
# 4         86653        3692  Master semestre 2        3692  Berlier Guillaume
#
#          section
# 0  Bioingénierie
# 1  Bioingénierie
# 2  Bioingénierie
# 3  Bioingénierie
# 4  Bioingénierie

# %%
df_student_by_year = df_complete[['course_name', 'year', 'student_id', 'semester']]
df_student_by_year = df_student_by_year.groupby(['course_name', 'year']).agg('count')\
    .sort_values('student_id', ascending=False).drop(axis=1, columns=['semester'])\
    .rename(columns={'student_id': 'nr_students'})
df_student_by_year.head()
# Out:
#                                        nr_students
# course_name                 year
# Chimie générale             2012-2013         1208
# Analyse III                 2018-2019         1133
#                             2019-2020         1103
# Probabilités et statistique 2013-2014         1015
# Chimie générale             2011-2012          995

# %%
df_student_by_year.to_csv('../../data/csv/server/students_by_year_v0.csv')

# %% [markdown]
# ## 3. Number of students divided by year of enrollment

# %%
df_student_by_enroyear = df_complete[['course_name', 'year', 'student_id', 'semester']]
df_student_by_enroyear = df_student_by_enroyear.groupby(['course_name', 'year', 'semester']).agg('count')\
    .rename(columns={'student_id': 'nr_students'}).reset_index()
df_student_by_enroyear.head()
# Out:
#                             course_name       year           semester  \
# 0   Numerical approximation of PDE's II  2012-2013  Master semestre 2
# 1   Numerical approximation of PDE's II  2013-2014  Master semestre 2
# 2   Numerical approximation of PDE's II  2013-2014  Master semestre 4
# 3   Numerical approximation of PDE's II  2014-2015  Master semestre 2
# 4   Numerical approximation of PDE's II  2015-2016  Master semestre 2
#
#    nr_students
# 0            7
# 1            4
# 2            1
# 3            4
# 4           11

# %%
df_student_by_enroyear.to_csv('../../data/csv/server/students_by_enroyear_v0.csv')

# %% [markdown]
# ## 4. Number of students by section

# %%
df_student_by_section = df_complete[['course_name', 'year', 'student_id', 'section']]
df_student_by_section = df_student_by_section.groupby(['course_name', 'year', 'section']).agg('count')\
    .rename(columns={'student_id': 'nr_students'}).reset_index()
df_student_by_section.head()
# Out:
#                             course_name       year  \
# 0   Numerical approximation of PDE's II  2012-2013
# 1   Numerical approximation of PDE's II  2012-2013
# 2   Numerical approximation of PDE's II  2012-2013
# 3   Numerical approximation of PDE's II  2013-2014
# 4   Numerical approximation of PDE's II  2013-2014
#
#                                    section  nr_students
# 0                  Ingénierie mathématique            4
# 1                   Mathématiques - master            1
# 2  Science et ingénierie computationnelles            2
# 3                  Ingénierie mathématique            1
# 4                   Mathématiques - master            2

# %%
df_student_by_section.to_csv('../../data/csv/server/students_by_section_v0.csv')

# %%
df_student_by_section[df_student_by_section['course_name'] == 'Machine learning']
# Out:
#             course_name       year  \
# 13041  Machine learning  2017-2018
# 13042  Machine learning  2017-2018
# 13043  Machine learning  2017-2018
# 13044  Machine learning  2017-2018
# 13045  Machine learning  2017-2018
# 13046  Machine learning  2017-2018
# 13047  Machine learning  2017-2018
# 13048  Machine learning  2017-2018
# 13049  Machine learning  2018-2019
# 13050  Machine learning  2018-2019
# 13051  Machine learning  2018-2019
# 13052  Machine learning  2018-2019
# 13053  Machine learning  2018-2019
# 13054  Machine learning  2018-2019
# 13055  Machine learning  2018-2019
# 13056  Machine learning  2018-2019
# 13057  Machine learning  2018-2019
# 13058  Machine learning  2018-2019
# 13059  Machine learning  2018-2019
# 13060  Machine learning  2018-2019
# 13061  Machine learning  2018-2019
# 13062  Machine learning  2019-2020
# 13063  Machine learning  2019-2020
# 13064  Machine learning  2019-2020
# 13065  Machine learning  2019-2020
# 13066  Machine learning  2019-2020
# 13067  Machine learning  2019-2020
# 13068  Machine learning  2019-2020
# 13069  Machine learning  2019-2020
# 13070  Machine learning  2019-2020
# 13071  Machine learning  2019-2020
# 13072  Machine learning  2019-2020
# 13073  Machine learning  2019-2020
# 13074  Machine learning  2019-2020
# 13075  Machine learning  2019-2020
# 13076  Machine learning  2019-2020
# 13077  Machine learning  2019-2020
#
#                                            section  nr_students
# 13041                                 Data Science           15
# 13042                                 Informatique          168
# 13043               Informatique et communications            7
# 13044   Management, technologie et entrepreneuriat            1
# 13045                       Mineur en Biocomputing            1
# 13046      Science et ingénierie computationnelles            9
# 13047  Sciences et technologies du vivant - master            8
# 13048           Systèmes de communication - master           19
# 13049                                 Data Science           36
# 13050                             Génie électrique            5
# 13051             Génie électrique et électronique           29
# 13052                          Humanités digitales            8
# 13053                                 Informatique          145
# 13054               Informatique et communications            9
# 13055            Ingénierie des sciences du vivant           24
# 13056                        Ingénierie financière            4
# 13057   Management, technologie et entrepreneuriat            4
# 13058                       Mineur en Informatique            2
# 13059      Science et ingénierie computationnelles           15
# 13060  Sciences et technologies du vivant - master            1
# 13061           Systèmes de communication - master            9
# 13062                                 Data Science           27
# 13063                             Génie électrique            3
# 13064             Génie électrique et électronique           23
# 13065                          Humanités digitales            1
# 13066                                 Informatique          114
# 13067                 Informatique - Cybersecurity            1
# 13068               Informatique et communications            8
# 13069            Ingénierie des sciences du vivant           67
# 13070                        Ingénierie financière           19
# 13071   Management, technologie et entrepreneuriat            4
# 13072                       Mineur en Biocomputing            1
# 13073                       Mineur en Informatique            1
# 13074    Mineur en Neurosciences computationnelles            1
# 13075      Science et ingénierie computationnelles           12
# 13076  Sciences et technologies du vivant - master            1
# 13077           Systèmes de communication - master            7

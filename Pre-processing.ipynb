# %% [markdown]
# At the beginning we have tried to fix the data since the data crawled were corrupted. See code below commented: \ Ref: https://medium.com/@jerilkuriakose/recover-corrupt-excel-file-xls-or-xlsx-using-python-2eea6bb07aae

# %% [markdown]
# ```
# # Changing the data types of all strings in the module at once
# from __future__ import unicode_literals
# from xlwt import Workbook
# import io
#
# filename = r'data/1.xls'
# file1 = io.open(filename, "r", encoding="utf-",errors='replace')
#
# data = file1.readlines()
#
# # Creating a workbook object
# xldoc = Workbook()
# sheet = xldoc.add_sheet("Sheet1", cell_overwrite_ok=True)
# for i, row in enumerate(data):
#     for j, val in enumerate(row.replace('\n', '').split('\t')):
#         sheet.write(i, j, val)
#
# xldoc.save('myexcel.xls')
# ```

# %% [markdown]
# After future analysis we have realized that data are saved into a xls format

# %%
import pandas as pd
df = pd.read_html('data/1007.xls')

# %%
df[1]
# Out:
#                        0                                            1   2
# 0   Dilnesa Belay Zeleke  Science et génie des matériaux (edoc), EDOC NaN
# 1             Ding Laura        Chimie et génie chimique (edoc), EDOC NaN
# 2            Fanget Axel                        Physique (edoc), EDOC NaN
# 3      Geissbühler Jonas  Science et génie des matériaux (edoc), EDOC NaN
# 4  Schuler Josef Andreas  Science et génie des matériaux (edoc), EDOC NaN
# 5          Spina Massimo                        Physique (edoc), EDOC NaN

# %%
df[0]
# Out:
#    CCMX Advanced Course - Atomic Force Microscopy (AFM): Theory and Practice  \
# 0    Science et génie des matériaux (edoc), 2011-2012
# 1   Dilnesa Belay ZelekeScience et génie des matér...
# 2    Science et génie des matériaux (edoc), 2012-2013
# 3   Benmessaoud Ryma InessBiotechnologie et génie ...
# 4   CCMX Advanced Course - Atomic Force Microscopy...
# 5    Science et génie des matériaux (edoc), 2015-2016
# 6   Achour HamedPhysique (edoc), EDOCAnantharaman ...
# 7                                                 NaN
# 8                                                 NaN
# 9    Science et génie des matériaux (edoc), 2013-2014
# 10  Hafner Regina JudithScience et génie des matér...
# 11   Science et génie des matériaux (edoc), 2014-2015
# 12  Matteini FedericoScience et génie des matériau...
#
#      Enseignant-e-(s): Hug Hans Josef, Mueller Daniel
# 0    Science et génie des matériaux (edoc), 2011-2012
# 1   Dilnesa Belay ZelekeScience et génie des matér...
# ...
